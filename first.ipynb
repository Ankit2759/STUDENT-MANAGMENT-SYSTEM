# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankit2759/STUDENT-MANAGMENT-SYSTEM/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Print Hello World

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Importing the libraries

# %%
import numpy as np

# %% [markdown]
# Array Creation

# %%
a = np.array([[1,2,3],[4,5,6]])
b = np.array([[1,2],[3,4],[5,6]])
print(a)
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
print(a.shape)
print(b.shape)
# Out:
# (2, 3)
# (3, 2)

# %% [markdown]
# Size of Array

# %%
print("A=",a)
print("B=",b)
print("Size of A=",a.shape)
print("Size of B=",b.shape)
# Out:
# A= [[1 2 3]
#  [4 5 6]]
# B= [[1 2]
#  [3 4]
#  [5 6]]
# Size of A= (2, 3)
# Size of B= (3, 2)

# %% [markdown]
# Opencv-- open source computer vision
#    importing cv2

# %%
import cv2

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/peppers.jpeg')
cv2_imshow(img)
print(img.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=240x180>
# (180, 240, 3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
imageR = img[:,:,0]
imageG = img[:,:,1]
imageB = img[:,:,2]

#imageRG= np.zeros((img.shape[0],img.shape[1],3))
#imageRG[:,:,0] = imageR
#imageRG[:,:,1] = imageB
cv2_imshow(imageR)
cv2_imshow(imageG)
cv2_imshow(imageB)
# Out:
# <PIL.Image.Image image mode=L size=240x180>
# <PIL.Image.Image image mode=L size=240x180>
# <PIL.Image.Image image mode=L size=240x180>

# %% [markdown]
# DIMENSIONS OF IMAGES

# %%
print(img.shape) #it shows all dimensions in only one command height width and channel respectively
print("height:", img.shape[0])
print("width:", img.shape[1])
print("channel:", img.shape[2])
# Out:
# (180, 240, 3)
# height: 180
# width: 240
# channel: 3

# %% [markdown]
# Importing matplot library for plotting graph

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Display Channel of Image

# %%
#display channel of image
imgR = img[:,:,0]
plt.imshow(imgR)

# %%
imgG=img[:,:,1]
plt.imshow(imgG)

# %%
imgB=img[:,:,2]
plt.imshow(imgB)

# %% [markdown]
# CONVERT TO grayscale

# %%
im_gray = cv2.imread('/content/peppers.jpeg',cv2.IMREAD_GRAYSCALE)
cv2_imshow(im_gray)
# Out:
# <PIL.Image.Image image mode=L size=240x180>

# %%
#write image to different file name
#(destination, source)
cv2.imwrite('/content/gray.jpg',im_gray)
# Out:
# True

# %% [markdown]
# Rotate the image

# %%
#rotate the image
img_rotate_90_clockwise = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
#plt.subplot(1,6,1)
#cv2_imshow(img_rotate_90_clockwise)
plt.imshow(img_rotate_90_clockwise)
plt.title("img_rotate_90_clockwise");
